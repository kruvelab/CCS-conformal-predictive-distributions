# %% [markdown]
# Notebook to perform additional experiments with alternative approaches to absolute maximum common-edge subgraph (MCES) molecular distances for the error function.
#
# The experiments were performed using the CCS model KerasECFP.

# %% [markdown]
# Environments:
# - base
#     - python 3.12.7
#     - scikit-learn 1.7.1
#     - matplotlib 3.10.0
# - Keras
#     - python 3.12.9
#     - keras 3.9.2
#     - scikit-learn 1.6.1
#     - matplotlib 3.10.0
# - cvxpy
#     - python 3.13.9
#     - cvxpy 1.7.2
#     - matplotlib 3.10.8

# %% [markdown]
# # Normalized MCES distances

# %%
# base


import numpy as np
import pandas as pd
import pickle

import matplotlib.pyplot as plt

# %%
Ucal = np.load('CALmyopicMCES.npy') # calibration MCES distance matrix 
print(f'Calibration MCES distance matrix: {Ucal.shape}')
normUcal = np.load('CALmyopicMCESnorm.npy') # calibration normalized MCES distance matrix 
print(f'Calibration normalized MCES distance matrix: {normUcal.shape}')
# Out:
# Calibration MCES distance matrix: (5805, 6668)
# Calibration normalized MCES distance matrix: (5805, 6668)

# %%
mces_cal = np.mean(np.partition(Ucal, kth = 48, axis = 1)[:, :48], axis=1).astype(np.float64)
mces_cal.shape
# Out:
# (5805,)

# %%
y_hat_cal = np.load('y_hat_calKerasECFP.npy') # CCS prediction for the final calibrants from the final KerasECFP model
print(f'Number of final KerasECFP calibration predictions: {y_hat_cal.size}')

with open("final_fold_idxs.pkl", 'rb') as f:
    final_fold = pickle.load(f) # tuple of two arrays with the indexes of METLIN-CCS for the final training and calibration splits
print(f'Size of training set: {final_fold[0].size} --- Size of calibration set: {final_fold[1].size}')
clean_metlin = pd.read_csv('METLINclean.csv')
abs_errors = np.abs(clean_metlin.CCS.iloc[final_fold[1]] - y_hat_cal).to_numpy()
# Out:
# Number of final KerasECFP calibration predictions: 5805
# Size of training set: 52236 --- Size of calibration set: 5805

# %%
norm_mces_cal = np.mean(np.partition(normUcal, kth = 48, axis = 1)[:, :48], axis=1).astype(np.float64)
norm_mces_cal.shape

fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(norm_mces_cal, abs_errors)
axes[1].scatter(mces_cal, abs_errors)
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Variance/standard deviation of ensemble

# %% [markdown]
# ## 5x5 cross-validation

# %%
# base


import numpy as np
import pandas as pd
import pickle

import matplotlib.pyplot as plt

# %%
YhatCVcal = np.load('YhatCVcalKerasECFP.npy') # CCS prediction for the final calibrants from the 25 CV models
YhatCVcal.shape
# Out:
# (5805, 25)

# %%
CVvars_cal = np.var(YhatCVcal, axis=1, ddof=1)
CVstds_cal = np.std(YhatCVcal, axis=1, ddof=1)

# %%
y_hat_cal = np.load('y_hat_calKerasECFP.npy') # CCS prediction for the final calibrants from the final KerasECFP model
y_hat_calCV = np.mean(YhatCVcal, axis=1) # CCS prediction for the final calibrants from the CV KerasECFP models
print(f'Final KerasECFP: {y_hat_cal.shape} --- CV KerasECFP: {y_hat_calCV.shape}')
# Out:
# Final KerasECFP: (5805,) --- CV KerasECFP: (5805,)

# %%
with open("final_fold_idxs.pkl", 'rb') as f:
    final_fold = pickle.load(f) # tuple of two arrays with the indexes of METLIN-CCS for the final training and calibration splits
print(f'Size of training set: {final_fold[0].size} --- Size of calibration set: {final_fold[1].size}')

clean_metlin = pd.read_csv('METLINclean.csv')
abs_errors = np.abs(clean_metlin.CCS.iloc[final_fold[1]] - y_hat_cal).to_numpy()
abs_errorsCV = np.abs(clean_metlin.CCS.iloc[final_fold[1]] - y_hat_calCV).to_numpy()
# Out:
# Size of training set: 52236 --- Size of calibration set: 5805

# %%
Ucal = np.load('CALmyopicMCES.npy') # calibration MCES distance matrix 
print(f'Calibration MCES distance matrix: {Ucal.shape}')
# Out:
# Calibration MCES distance matrix: (5805, 6668)

# %%
mces_cal = np.mean(np.partition(Ucal, kth = 48, axis = 1)[:, :48], axis=1).astype(np.float64)
mces_cal.shape
# Out:
# (5805,)

# %%
# CV variance againsts CV absolute errors
fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(CVvars_cal, abs_errorsCV)
axes[1].scatter(mces_cal, abs_errorsCV)
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()

# %%
# CV standard devs againsts CV absolute errors
fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(CVstds_cal, abs_errorsCV)
axes[1].scatter(mces_cal, abs_errorsCV)
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()

# %%
# CV var againsts final GraphCCS abs errors
fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(CVvars_cal, abs_errors)
axes[1].scatter(mces_cal, abs_errors)
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()

# %%
# CV stds againsts final GraphCCS abs errors
fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(CVstds_cal, abs_errors)
axes[1].scatter(mces_cal, abs_errors)
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Random forest treeSD

# %%
# base


import numpy as np
import pandas as pd
import pickle

from itertools import product
from sklearn.metrics import r2_score
from tqdm import tqdm
from sklearn.ensemble import RandomForestRegressor

import matplotlib.pyplot as plt

# %%
with open("final_fold_idxs.pkl", 'rb') as f:
    final_fold = pickle.load(f) # tuple of two arrays with the indexes of METLIN-CCS for the final training and calibration splits
print(f'Size of training set: {final_fold[0].size} --- Size of calibration set: {final_fold[1].size}')
# Out:
# Size of training set: 52236 --- Size of calibration set: 5805

# %%
y = pd.read_csv("METLINclean.csv", usecols=['CCS']).to_numpy().flatten()
y_train = y[final_fold[0]]
y_cal = y[final_fold[1]]

X = pd.read_csv('FGPs.csv', index_col=0).to_numpy() # ECFP2 fingerprints for METLIN-CCS with concatenated m/z and one-hot-encoded ion type
print(f'Fingerprint matrix: {X.shape}')
Xtrain = X[final_fold[0]]
Xcal = X[final_fold[1]]
# Out:
# Fingerprint matrix: (58041, 1028)

# %%
n_estimators = [200, 500, 1000]
max_features = [1/3, 'log2', 1.]
min_samples_leaf = [1, 3, 6, 12]

combos = [combo for combo in product(n_estimators, max_features, min_samples_leaf)]

results = []
for combo in combos:
    rf_ccs = RandomForestRegressor(n_estimators=combo[0], max_features=combo[1], min_samples_leaf=combo[2], n_jobs=15)
    rf_ccs.fit(X, y_train)
    rf_hat_train = rf_ccs.predict(Xtrain)
    rf_hat_cal = rf_ccs.predict(Xcal)

    results.append([
        r2_score(y_train, rf_hat_train), 100 * np.percentile(np.abs(y_train - rf_hat_train) / y_train, 90, method = 'nearest'),
        r2_score(y_cal, rf_hat_cal), 100 * np.percentile(np.abs(y_cal - rf_hat_cal) / y_cal, 90, method = 'nearest')
    ])
# Out:
# 36it [2:10:52, 218.12s/it]

# %%
results_df = pd.DataFrame(results, index=combos, 
                          columns=['R2train', 'PAEtrain', 'R2cal', 'PAEcal'])

# %%
results_df.assign(diff=abs(results_df['PAEtrain'] - results_df['PAEcal'])).sort_values('diff').drop(columns='diff')
# Out:
#                                  R2train  PAEtrain     R2cal    PAEcal
# (1000, log2, 12)                0.551240  9.464642  0.523619  9.649369
# (200, log2, 12)                 0.542652  9.546603  0.515177  9.736666
# (500, log2, 12)                 0.546999  9.521066  0.518489  9.719945
# (200, log2, 6)                  0.628165  8.604400  0.581098  9.033279
# (500, log2, 6)                  0.619632  8.701174  0.572775  9.143427
# (1000, log2, 6)                 0.628553  8.591819  0.581894  9.051376
# (500, 0.3333333333333333, 12)   0.889298  4.521561  0.849014  5.274614
# (1000, 0.3333333333333333, 12)  0.889405  4.518227  0.849031  5.296192
# (200, 0.3333333333333333, 12)   0.888871  4.526476  0.848401  5.308655
# (500, log2, 3)                  0.721049  7.436687  0.640428  8.340391
# (500, 1.0, 12)                  0.897457  4.319235  0.848851  5.245713
# (1000, 1.0, 12)                 0.897596  4.311183  0.849002  5.243920
# (200, 1.0, 12)                  0.897386  4.319466  0.848581  5.258093
# (1000, log2, 3)                 0.721697  7.425553  0.640318  8.382221
# (200, log2, 3)                  0.722075  7.414691  0.641082  8.388023
# (1000, 0.3333333333333333, 6)   0.921095  3.779153  0.858688  5.106641
# (500, 0.3333333333333333, 6)    0.920969  3.781486  0.858310  5.114246
# (200, 0.3333333333333333, 6)    0.920924  3.776972  0.859120  5.115098
# (500, 1.0, 6)                   0.929711  3.540520  0.856664  5.068663
# (200, 1.0, 6)                   0.929578  3.539160  0.855937  5.076035
# (1000, 1.0, 6)                  0.929813  3.540595  0.856568  5.079361
# (1000, 0.3333333333333333, 3)   0.953578  2.851460  0.865237  4.939858
# (500, 0.3333333333333333, 3)    0.953532  2.855653  0.865278  4.975067
# (200, 0.3333333333333333, 3)    0.953117  2.872838  0.864937  4.996264
# (1000, 1.0, 3)                  0.959998  2.615166  0.860428  5.005488
# (200, 1.0, 3)                   0.959685  2.628354  0.859970  5.021148
# (500, 1.0, 3)                   0.959942  2.617008  0.860348  5.029700
# (200, 0.3333333333333333, 1)    0.982200  1.804909  0.866347  4.934196
# (200, 1.0, 1)                   0.981298  1.848595  0.860265  4.990837
# (500, 0.3333333333333333, 1)    0.982444  1.791628  0.866424  4.968302
# (1000, 0.3333333333333333, 1)   0.982547  1.783112  0.866437  4.960476
# (1000, 1.0, 1)                  0.981716  1.829916  0.860895  5.007332
# (500, 1.0, 1)                   0.981615  1.834038  0.860016  5.039310
# (200, log2, 1)                  0.970021  2.358965  0.775453  6.409393
# (1000, log2, 1)                 0.970601  2.338464  0.775801  6.400607
# (500, log2, 1)                  0.970442  2.348854  0.776198  6.423851

# %%
rf_ccs = RandomForestRegressor(n_estimators=500, max_features=1/3, min_samples_leaf=12, n_jobs=15)
rf_ccs.fit(Xtrain, y_train)
# Out:
# RandomForestRegressor(max_features=0.3333333333333333, min_samples_leaf=12,
#                       n_estimators=500, n_jobs=15)

# %%
rfYhat_train = np.asarray([tree.predict(Xtrain) for tree in tqdm(rf_ccs.estimators_)])
# Out:
# 100%|██████████| 500/500 [00:53<00:00,  9.40it/s]

# %%
treeSD = np.std(rfYhat_train, axis=0, ddof=1)

# %%
Utrain = np.load('train_myopicMCES.npy') # training MCES distance matrix 
print(f'Training MCES distance matrix: {Utrain.shape}')
mces_train = np.mean(np.partition(Utrain, kth = 48, axis = 1)[:, :48], axis=1).astype(np.float64)
# Out:
# Training MCES distance matrix: (52236, 6668)

# %%
y_hat_train = np.load('y_hat_trainKerasECFP.npy') # CCS prediction for the final training set from the final KerasECFP model
print(f'Number of final KerasECFP training predictions: {y_hat_train.size}')
# Out:
# Number of final KerasECFP training predictions: 52236

# %%
y_hat_train_rf = np.mean(rfYhat_train, axis = 0)

# %%
abs_errors = np.abs(y_train - y_hat_train)
abs_errors_rf = np.abs(y_train - y_hat_train_rf)

# %%
fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(treeSD, abs_errors_rf)
axes[1].scatter(mces_train, abs_errors_rf)
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(treeSD, abs_errors)
axes[1].scatter(mces_train, abs_errors)
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Error model

# %% [markdown]
# ## Random forest regressor on a feature space composed of m/z, cross-validation ensemble standard deviation, CCShat as well as one-hot-encoded ion type

# %%
# base


import pickle as pkl
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor

import matplotlib.pyplot as plt

# %%
Ucal = np.load('CALmyopicMCES.npy') # calibration MCES distance matrix 
print(f'Calibration MCES distance matrix: {Ucal.shape}')

mces_cal = np.mean(np.partition(Ucal, kth = 48, axis = 1)[:, :48], axis=1).astype(np.float64)
# Out:
# Calibration MCES distance matrix: (5805, 6668)

# %%
YhatCVcal = np.load('YhatCVcalKerasECFP.npy') # CCS prediction for the final calibrants from the 25 CV models

CVstds_cal = np.std(YhatCVcal, axis=1, ddof=1)

# %%
y_hat_cal = np.load('y_hat_calKerasECFP.npy') # CCS prediction for the final calibrants from the final KerasECFP model
print(f'Number of final KerasECFP calibration predictions: {y_hat_cal.size}')
# Out:
# Number of final KerasECFP calibration predictions: 5805

# %%
with open("final_fold_idxs.pkl", 'rb') as f:
    final_fold = pkl.load(f) # tuple of two arrays with the indexes of METLIN-CCS for the final training and calibration splits
print(f'Size of training set: {final_fold[0].size} --- Size of calibration set: {final_fold[1].size}')

ion_info = pd.read_csv('FGPs.csv', index_col=0).to_numpy()[final_fold[1], -4:] # m/z and one-hot-encoded ion type
# Out:
# Size of training set: 52236 --- Size of calibration set: 5805

# %%
Xtrain = np.hstack((mces_cal.reshape(-1, 1), CVstds_cal.reshape(-1, 1), y_hat_cal.reshape(-1, 1), ion_info))

# %%
Xtrain.shape
# Out:
# (5805, 7)

# %%
Xtrain[0]
# Out:
# array([  9.2890625 ,   1.22033179, 186.4949646 , 348.1319    ,
#          0.        ,   1.        ,   0.        ])

# %%
y_cal = pd.read_csv("METLINclean.csv", usecols=['CCS']).to_numpy().flatten()[final_fold[1]]
y_train = np.abs(y_cal - y_hat_cal)

# %%
rf = RandomForestRegressor(n_estimators=100, min_samples_leaf=6, max_features=1/3, n_jobs=15) 
rf.fit(Xtrain[:-1000], y_train[:-1000])
# Out:
# RandomForestRegressor(max_features=0.3333333333333333, min_samples_leaf=6,
#                       n_jobs=15)

# %%
fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(rf.predict(Xtrain[:-1000]), y_train[:-1000])
axes[1].scatter(mces_cal[:-1000], y_train[:-1000])
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(rf.predict(Xtrain[-1000:]), y_train[-1000:])
axes[1].scatter(mces_cal[-1000:], y_train[-1000:])
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ECFPs

# %% [markdown]
# ### Random forest

# %%
# base


import pickle
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor

import matplotlib.pyplot as plt

# %%
with open("final_fold_idxs.pkl", 'rb') as f:
    final_fold = pickle.load(f) # tuple of two arrays with the indexes of METLIN-CCS for the final training and calibration splits
print(f'Size of training set: {final_fold[0].size} --- Size of calibration set: {final_fold[1].size}')

ccs = pd.read_csv("METLINclean.csv", usecols=['CCS']).to_numpy().flatten()
X = pd.read_csv('FGPs.csv', index_col=0).to_numpy()
# Out:
# Size of training set: 52236 --- Size of calibration set: 5805

# %%
ccs_hat_train = np.load('y_hat_trainKerasECFP.npy')
y_train = np.abs(ccs[final_fold[0]] - ccs_hat_train)
Xtrain = X[final_fold[0]]

# %%
Utrain = np.load('train_myopicMCES.npy') # training MCES distance matrix 
print(f'Training MCES distance matrix: {Utrain.shape}')
mces_train = np.mean(np.partition(Utrain, kth = 48, axis = 1)[:, :48], axis=1).astype(np.float64)
# Out:
# Training MCES distance matrix: (52236, 6668)

# %%
ccs_hat_cal = np.load('y_hat_calKerasECFP.npy')
y_cal = np.abs(ccs[final_fold[1]] - ccs_hat_cal)
Xcal = X[final_fold[1]]

# %%
Ucal = np.load('CALmyopicMCES.npy') # calibration MCES distance matrix 
print(f'Calibration MCES distance matrix: {Ucal.shape}')
mces_cal = np.mean(np.partition(Ucal, kth = 48, axis = 1)[:, :48], axis=1).astype(np.float64)
# Out:
# Calibration MCES distance matrix: (5805, 6668)

# %%
rf = RandomForestRegressor(n_estimators=500, max_features=1/3, min_samples_leaf=6, n_jobs=15)
rf.fit(Xtrain, y_train)
# Out:
# RandomForestRegressor(max_features=0.3333333333333333, min_samples_leaf=6,
#                       n_estimators=500, n_jobs=15)

# %%
fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(rf.predict(Xtrain), y_train)
axes[1].scatter(mces_train, y_train)
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(rf.predict(Xcal), y_cal)
axes[1].scatter(mces_cal, y_cal)
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### SVR

# %%
# base


import pickle
import pandas as pd
import numpy as np

from sklearn.svm import SVR
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt

# %%
with open("final_fold_idxs.pkl", 'rb') as f:
    final_fold = pickle.load(f) # tuple of two arrays with the indexes of METLIN-CCS for the final training and calibration splits
print(f'Size of training set: {final_fold[0].size} --- Size of calibration set: {final_fold[1].size}')

ccs = pd.read_csv("METLINclean.csv", usecols=['CCS']).to_numpy().flatten()
X = pd.read_csv('FGPs.csv', index_col=0).to_numpy()
# Out:
# Size of training set: 52236 --- Size of calibration set: 5805

# %%
ccs_hat_train = np.load('y_hat_trainKerasECFP.npy')
y_train = np.abs(ccs[final_fold[0]] - ccs_hat_train)
Xtrain = X[final_fold[0]]

# %%
Utrain = np.load('train_myopicMCES.npy') # training MCES distance matrix 
print(f'Training MCES distance matrix: {Utrain.shape}')
mces_train = np.mean(np.partition(Utrain, kth = 48, axis = 1)[:, :48], axis=1).astype(np.float64)
# Out:
# Training MCES distance matrix: (52236, 6668)

# %%
ccs_hat_cal = np.load('y_hat_calKerasECFP.npy')
y_cal = np.abs(ccs[final_fold[1]] - ccs_hat_cal)
Xcal = X[final_fold[1]]

# %%
Ucal = np.load('CALmyopicMCES.npy') # calibration MCES distance matrix 
print(f'Calibration MCES distance matrix: {Ucal.shape}')
mces_cal = np.mean(np.partition(Ucal, kth = 48, axis = 1)[:, :48], axis=1).astype(np.float64)
# Out:
# Calibration MCES distance matrix: (5805, 6668)

# %%
vthr = VarianceThreshold()
Xtrain_trans = vthr.fit_transform(Xtrain)
scaler = StandardScaler()
Xtrain_trans = scaler.fit_transform(Xtrain_trans)

# %%
Xcal_trans = scaler.transform(vthr.transform(Xcal))

# %%
svr = SVR()
svr.fit(Xtrain_trans, y_train)
# Out:
# SVR()

# %%
fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(svr.predict(Xtrain_trans), y_train)
axes[1].scatter(mces_train, y_train)
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(svr.predict(Xcal_trans), y_cal)
axes[1].scatter(mces_cal, y_cal)
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Feed-forward neural network

# %%
# Keras


import pickle
import numpy as np
import pandas as pd

import tensorflow as tf
print("GPUs:", tf.config.list_physical_devices('GPU'))
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

import matplotlib.pyplot as plt
# Out:
# GPUs: []

# %%
with open("final_fold_idxs.pkl", 'rb') as f:
    final_fold = pickle.load(f) # tuple of two arrays with the indexes of METLIN-CCS for the final training and calibration splits
print(f'Size of training set: {final_fold[0].size} --- Size of calibration set: {final_fold[1].size}')

ccs = pd.read_csv("METLINclean.csv", usecols=['CCS']).to_numpy().flatten()
X = pd.read_csv('FGPs.csv', index_col=0).to_numpy()
# Out:
# Size of training set: 52236 --- Size of calibration set: 5805

# %%
ccs_hat_train = np.load('y_hat_trainKerasECFP.npy')
y_train = np.abs(ccs[final_fold[0]] - ccs_hat_train)
Xtrain = X[final_fold[0]]

# %%
Utrain = np.load('train_myopicMCES.npy') # training MCES distance matrix 
print(f'Training MCES distance matrix: {Utrain.shape}')
mces_train = np.mean(np.partition(Utrain, kth = 48, axis = 1)[:, :48], axis=1).astype(np.float64)
# Out:
# Training MCES distance matrix: (52236, 6668)

# %%
ccs_hat_cal = np.load('y_hat_calKerasECFP.npy')
y_cal = np.abs(ccs[final_fold[1]] - ccs_hat_cal)
Xcal = X[final_fold[1]]

# %%
Ucal = np.load('CALmyopicMCES.npy') # calibration MCES distance matrix 
print(f'Calibration MCES distance matrix: {Ucal.shape}')
mces_cal = np.mean(np.partition(Ucal, kth = 48, axis = 1)[:, :48], axis=1).astype(np.float64)
# Out:
# Calibration MCES distance matrix: (5805, 6668)

# %%
model = Sequential(
    [   
        Input(shape=(Xtrain.shape[1],)),
        Dense(1028, activation='relu'),
        Dense(512,  activation='relu'),
        Dense(32,   activation='relu'),
        Dense(1,    activation='linear')
    ]
)
model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=1e-4))
history = model.fit(Xtrain, y_train, batch_size = 128, epochs = 70)
# Out:
# Epoch 1/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 14.0852
# Epoch 2/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 9.8603
# Epoch 3/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 9.2041
# Epoch 4/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 9.3871
# Epoch 5/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 9.1267
# Epoch 6/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 9.2249
# Epoch 7/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 9.0449
# Epoch 8/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 9.1110
# Epoch 9/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 9.1937
# Epoch 10/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 9.4311
# Epoch 11/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 9.0166
# Epoch 12/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 9.0122
# Epoch 13/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 9.0527
# Epoch 14/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 8.6812
# Epoch 15/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 8.6015
# Epoch 16/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 8.6379
# Epoch 17/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 8.7152
# Epoch 18/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 8.1882
# Epoch 19/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 8.4540
# Epoch 20/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 8.1868
# Epoch 21/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 8.3616
# Epoch 22/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 8.1558
# Epoch 23/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 8.2997
# Epoch 24/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 8.1709
# Epoch 25/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 8.0418
# Epoch 26/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 7.9809
# Epoch 27/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 8.1407
# Epoch 28/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - loss: 7.8398
# Epoch 29/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 7.7818
# Epoch 30/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 7.5749
# Epoch 31/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 7.7888
# Epoch 32/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 7.7199
# Epoch 33/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 7.7874
# Epoch 34/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 7.3995
# Epoch 35/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 7.1506
# Epoch 36/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 7.2395
# Epoch 37/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 7.3279
# Epoch 38/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 7.1505
# Epoch 39/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 7.0627
# Epoch 40/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 6.9309
# Epoch 41/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 6.5739
# Epoch 42/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 6.5635
# Epoch 43/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - loss: 6.7126
# Epoch 44/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 6.5748
# Epoch 45/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 6.4632
# Epoch 46/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 6.2001
# Epoch 47/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 5.9324
# Epoch 48/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - loss: 5.9953
# Epoch 49/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 5.9448
# Epoch 50/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 5.6216
# Epoch 51/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - loss: 5.5739
# Epoch 52/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 5.4008
# Epoch 53/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 5.3935
# Epoch 54/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 5.1561
# Epoch 55/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 5.1487
# Epoch 56/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 5.1604
# Epoch 57/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 4.9364
# Epoch 58/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 4.6379
# Epoch 59/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 4.7637
# Epoch 60/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 4.5251
# Epoch 61/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 4.4451
# Epoch 62/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 4.4604
# Epoch 63/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 4.2208
# Epoch 64/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 4.2774
# Epoch 65/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 4.0558
# Epoch 66/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 4.0573
# Epoch 67/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 4.0139
# Epoch 68/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 3.8556
# Epoch 69/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 3.8358
# Epoch 70/70
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 3.7217

# %%
plt.plot(history.history['loss'])

# %%
fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(model.predict(Xtrain).flatten(), y_train)
axes[1].scatter(mces_train, y_train)
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()
# Out:
# 1633/1633 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step

# %%
fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(model.predict(Xcal).flatten(), y_cal)
axes[1].scatter(mces_cal, y_cal)
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()
# Out:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %% [markdown]
# ## Potential SVR

# %%
# cvxpy


import pickle as pickle
import numpy as np
import pandas as pd

from PSVR import *

import matplotlib.pyplot as plt

# %%
with open("final_fold_idxs.pkl", 'rb') as f:
    final_fold = pickle.load(f) # tuple of two arrays with the indexes of METLIN-CCS for the final training and calibration splits
print(f'Size of training set: {final_fold[0].size} --- Size of calibration set: {final_fold[1].size}')

ccs_train = pd.read_csv("METLINclean.csv", usecols=['CCS']).to_numpy().flatten()[final_fold[0]]
ccs_hat_train = np.load('y_hat_trainKerasECFP.npy')
# Out:
# Size of training set: 52236 --- Size of calibration set: 5805

# %%
y_train = np.abs(ccs_train - ccs_hat_train)

# %%
Xtrain = np.load('ionMCEStrain.npy').astype(np.float32) # this is an MCES distance matrix
# calculated between ion graphs
# it contains the distances between all final training ions of GraphCCS and a subsample of it (the corresponding METLIN-CCS indexes are
# under finalPSVRidxs.npy)
Xtrain.shape
# Out:
# (52236, 5224)

# %%
Xtrain
# Out:
# array([[22. , 16. , 11. , ..., 20. , 17. , 14. ],
#        [19.5, 17.5, 21.5, ..., 21.5, 10.5, 13.5],
#        [17. , 13. , 13. , ..., 22. , 12. , 20. ],
#        ...,
#        [16. , 16. , 15. , ..., 30. , 19. , 11. ],
#        [21. , 20. , 15. , ..., 13. , 15. , 22. ],
#        [16. , 13. , 14. , ..., 21. , 11. , 19. ]],
#       shape=(52236, 5224), dtype=float32)

# %%
sum(Xtrain == 0).sum()
# Out:
# np.int64(5224)

# %%
stds = np.std(Xtrain, axis=0, ddof=1)

# %%
sum(stds <= 5), sum(stds > 5)
# Out:
# (np.int64(4365), np.int64(859))

# %%
Xtrain_norm = np.load('ionMCEStrain_norm.npy').astype(np.float32) # this is a normalized MCES distance matrix
# calculated between ion graphs
# it contains the distances between all final training ions of GraphCCS and a subsample of it (the corresponding METLIN-CCS indexes are
# under finalPSVRidxs.npy)
Xtrain_norm.shape
# Out:
# (52236, 5224)

# %%
stds_norm = np.std(Xtrain_norm, axis=0, ddof=1)
sum(stds_norm <= 0.1), sum(stds_norm > 0.1)
# Out:
# (np.int64(5000), np.int64(224))

# %% [markdown]
# ### For predicting CCS

# %%
psvr = PSVR(C = 100, epsilon=0.01, stdev_threshold=5)
psvr.fit(Xtrain, ccs_train)

# %%
fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(psvr.predict(Xtrain), ccs_train)
axes[1].scatter(ccs_hat_train, ccs_train)
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()

# %%
psvr = PSVR(C = 100, epsilon=0.01, stdev_threshold=0.1)
psvr.fit(Xtrain_norm, ccs_train)

# %%
fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(psvr.predict(Xtrain_norm), ccs_train)
axes[1].scatter(ccs_hat_train, ccs_train)
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### For predicting errors

# %%
Utrain = np.load('train_myopicMCES.npy') # training MCES distance matrix 
print(f'Training MCES distance matrix: {Utrain.shape}')
mces_train = np.mean(np.partition(Utrain, kth = 48, axis = 1)[:, :48], axis=1).astype(np.float64)
# Out:
# Training MCES distance matrix: (52236, 6668)

# %%
psvr = PSVR(C = 100, epsilon=0.01, stdev_threshold=5)
psvr.fit(Xtrain, y_train)

# %%
fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(psvr.predict(Xtrain), y_train)
axes[1].scatter(mces_train, y_train)
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()

# %%
psvr = PSVR(C = 100, epsilon=0.01, stdev_threshold=0.1)
psvr.fit(Xtrain_norm, y_train)

# %%
fig, axes = plt.subplots(1, 2, sharey=True)
axes[0].scatter(psvr.predict(Xtrain_norm), y_train)
axes[1].scatter(mces_train, y_train)
for ax in axes:
    ax.set_box_aspect(1)
plt.tight_layout()
plt.show()
